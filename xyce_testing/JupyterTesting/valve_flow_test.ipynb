# %%
import matplotlib

import sys, os
import subprocess

#print(os.getcwd())
sys.path.insert(0,os.getcwd()+'/../')

from plot_result import sum_cur
import plot_result

val_t_dir = os.getcwd()+'/../MFlibrary_testing/stdcellTesting/valve_flow'
plot_r = plot_result.plot_prn

lib = "./../../Components/verilogA_build/lib/MFXyce.so"

def run_xyce(lib, cir):
    if not os.path.isfile(lib):
        raise ValueError(lib + " library file does not exist") 

    if not os.path.isfile(cir):
        raise ValueError(cir + " not able to find ciruit file") 

    cir_root, fname = os.path.split(cir)
    
    subprocess.run(['sh', './../run_test.sh', lib, cir, cir_root])

def run_and_plot(lib, cir, plot_type=None, plot_nodes=None):

    cir_a = val_t_dir+'/'+cir
    prn   = val_t_dir+'/results/'+cir+'.prn'
    
    run_xyce(lib, cir_a)
    
    # only the definition above needs to be changed
    run_xyce(lib, cir_a)
    plot_r(prn, plot_type=plot_type, plot_nodes=plot_nodes)

# %%
# theory calculations

import numpy as np
import matplotlib.pyplot as plt


dt_cyc = 60*5 #ms

vol_p_st = np.linspace(0, 50e-12, 10000)

pump_fl = lambda dt, vol : 60/(dt*1e-3) * vol 

pump_fl_p = pump_fl(dt_cyc, vol_p_st)

plt.plot(vol_p_st, pump_fl_p)
plt.show()

pump_30nl = pump_fl(dt_cyc, 30e-12) 
print(pump_30nl)

# 60 ms calculations
vol_desc = 4*37e-12 * 60 /1e-9

print(f"vol desc:{vol_desc}")
# Out:
# 6e-09
# vol desc:8.88

# %%
#vs_f 1  0 5V
#vs_p 11 0 PWL(0s 0V 3m 0v 6m 105kV 10m 105kV)
#
#r1 1 2 1k
#r2 5 0 1k
#r3 11 12 1k
#r4 13 0 1M
#
#Yvalve_20px_1_V        valv1 3 31 11 0
#Ymembrane_cap_20pxV_Pn mem1  31 11
#Yvalve_20px_1_V        valv2 31 4 11 0
#
#vp1 2 3 0V
#vp2 4 5 0V
#
#.tran 0.01 10ms
#.print tran I(vp1) I(vp2) V(11)
#.end



plot_r(val_t_dir+'/results/valve_flow_test_1_0.cir.prn', plot_type='flow')
plot_r(val_t_dir+'/results/valve_flow_test_1_0.cir.prn', plot_type='voltage')
# Out:
# plot: valve_flow_test_1_0.cir.prn
# plot: valve_flow_test_1_0.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_flow_test_1_0_V.cir.prn')
# Out:
# plot: valve_flow_test_1_0_V.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_flow_test_1_0_1.cir.prn')
plot_r(val_t_dir+'/results/valve_flow_test_1_0_1_V.cir.prn')
# Out:
# plot: valve_flow_test_1_0_1.cir.prn
# plot: valve_flow_test_1_0_1_V.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_flow_test_1_0_1_1.cir.prn')
plot_r(val_t_dir+'/results/valve_flow_test_1_0_1_1_V.cir.prn')
# Out:
# plot: valve_flow_test_1_0_1_1.cir.prn
# plot: valve_flow_test_1_0_1_1_V.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_flow_test_1_0_2.cir.prn')
plot_r(val_t_dir+'/results/valve_flow_test_1_0_2_V.cir.prn')
# Out:
# plot: valve_flow_test_1_0_2.cir.prn
# plot: valve_flow_test_1_0_2_V.cir.prn

# %%
#plot_r(val_t_dir+'/valve_flow_test_1_0_2_V.cir.prn')

# %%
plot_r(val_t_dir+'/results/valve_flow_test_2_0.cir.prn')
plot_r(val_t_dir+'/results/valve_flow_test_2_0_V.cir.prn')
# Out:
# plot: valve_flow_test_2_0.cir.prn
# plot: valve_flow_test_2_0_V.cir.prn

# %%
cir = 'valve_flow_test_3_0.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0.cir.log
# plot: valve_flow_test_3_0.cir.prn
# plot: valve_flow_test_3_0.cir.prn
# vs_f 1  0 0V
# vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# vs_p2 12 0 PWL(0s 0V    6 0v    6.1 105kV 15 105kV 15.1   0V    20 0kV)
# vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# r1 1 2 1k
# r2 5 0 1k
#
#
# Yvalve_20px_1_V        valv1 3 31 11 0
# Ymembrane_cap_20pxV_Pn mem1  31 12
# Yvalve_20px_1_V        valv2 31 4 13 0
#
# vp1 3 2 0V
# vp2 5 4 0V
#
# .tran 0.01 20s
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end

# %%
import numpy as np
import matplotlib.pyplot as plt

r = 508e-6
E = 7.7e6
v = 0.3
th= 20e-6

D = E*th**3/(12*(1-v**2))
R = r

w = lambda r, p: p*R**4/(64*D) * (1 - (r/R)**2)**2

Pr = np.linspace(0, 103e3, 10000)

w_508 = Pr * R**4/(64*D)

plt.plot(Pr, w_508)
plt.show()

print("defl @ 4 psi")
print(w(0, 27.5e3)*1e6)
print("defl @ 2 psi")
print(w(0, 13.7e3)*1e6)
#print(Pr)

# 60 ms calculations
# Out:
# defl @ 4 psi
# 5072.820499499998
# defl @ 2 psi
# 2527.186939750908

# %%
cir = 'valve_flow_test_3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 4.0]) * 20 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)

# from publication
#
# 20 ms - 19-18 ul/min
# 30 ms - 15 ul/min
# 40 ms - 12-13 ul/min
# 60 ms - 10 ul/min

# at 4 psi flow rate - 368.4250383869166
# at 2 psi flow rate = 274.5705950843409
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1.cir.log
# plot: valve_flow_test_3_1.cir.prn
# plot: valve_flow_test_3_1.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# vs_p1 11 0 PULSE(0 105kV  0.5   1m 1m 20m 60m)
# vs_p2 12 0 PULSE(0 0.254kV 0.51  1m 1m 30m 60m)
# vs_p3 13 0 PULSE(0 105kV  0.53  1m 1m 20m 60m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_20px_1_V        valv1 3 31 11 0
# Ymembrane_cap_20pxV_Pn mem1  31 12 mem_r=504e-6
# Yvalve_20px_1_V        valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.0001 5s
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# 1409
# 9859
# start:1409 end:9859
# Index
# 1409    0.000000e+00
# 1410    0.000000e+00
# 1411    0.000000e+00
# 1412   -2.416807e-10
# 1413   -2.366497e-10
#             ...
# 9854    0.000000e+00
# 9855    0.000000e+00
# 9856    0.000000e+00
# 9857    0.000000e+00
# 9858    0.000000e+00
# Name: I(VP1), Length: 8450, dtype: float64
# 2.8919689966450837

# %%
cir = 'valve_flow_test_3_0_n3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

I_vp_t1 = sum_cur(tim, I_vp, [0.6, 0.80]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp_t2 = sum_cur(tim, I_vp, [1.0, 1.10]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp_t3 = sum_cur(tim, I_vp, [1.25,1.40]) # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0_n3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_0_n3_1.cir.log
# plot: valve_flow_test_3_0_n3_1.cir.prn
# plot: valve_flow_test_3_0_n3_1.cir.prn
# vs_f 1  0 0V
#
# vs_p1 11 0 0
# *PULSE(0kV 0   0.56   1m 1m 60m  300m)
# vs_p2 12 0 PULSE(6.9kV 0   0.56   1m 1m 180m 300m)
# vs_p3 13 0 0
# *PULSE(0kV 0   0.68   1m 1m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3_1 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.008ms 2.1s 0.4s 0.01ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 60050     2.176283e-24
# 60051    -2.176283e-24
# 60052     2.176283e-24
# 60053    -2.176283e-24
# 60054     2.176283e-24
#               ...
# 160193   -8.166026e-23
# 160194   -2.414572e-22
# 160195   -8.166026e-23
# 160196   -2.414572e-22
# 160197   -8.166026e-23
# Name: I(VP1), Length: 100148, dtype: float64
# Index
# 20011   -1.627662e-24
# 20012    1.627812e-24
# 20013   -1.627664e-24
# 20014    1.627810e-24
# 20015   -1.627666e-24
#              ...
# 40037   -8.166459e-23
# 40038   -2.414528e-22
# 40039   -8.166459e-23
# 40040   -2.414528e-22
# 40041   -8.166459e-23
# Name: I(VP1), Length: 20031, dtype: float64
# Index
# 60050    2.176283e-24
# 60051   -2.176283e-24
# 60052    2.176283e-24
# 60053   -2.176283e-24
# 60054    2.176283e-24
#              ...
# 70076   -8.169041e-23
# 70077   -2.414270e-22
# 70078   -8.169041e-23
# 70079   -2.414270e-22
# 70080   -8.169041e-23
# Name: I(VP1), Length: 10031, dtype: float64
# Index
# 85089    -1.321769e-24
# 85090     1.321769e-24
# 85091    -1.321769e-24
# 85092     1.321769e-24
# 85093    -1.321769e-24
#               ...
# 100115   -8.168159e-23
# 100116   -2.414358e-22
# 100117   -8.168159e-23
# 100118   -2.414358e-22
# 100119   -8.168159e-23
# Name: I(VP1), Length: 15031, dtype: float64
# 0.39066102590350904

# %%
# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

I_vp_t1 = sum_cur(tim, I_vp, [0.6, 0.80]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp_t2 = sum_cur(tim, I_vp, [1.0, 1.18]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp_t3 = sum_cur(tim, I_vp, [1.25,1.35]) # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
print(I_vp_t1)
print(I_vp_t2)
print(I_vp_t3)
# Out:
# Index
# 60050     2.176283e-24
# 60051    -2.176283e-24
# 60052     2.176283e-24
# 60053    -2.176283e-24
# 60054     2.176283e-24
#               ...
# 160193   -8.166026e-23
# 160194   -2.414572e-22
# 160195   -8.166026e-23
# 160196   -2.414572e-22
# 160197   -8.166026e-23
# Name: I(VP1), Length: 100148, dtype: float64
# Index
# 20011   -1.627662e-24
# 20012    1.627812e-24
# 20013   -1.627664e-24
# 20014    1.627810e-24
# 20015   -1.627666e-24
#              ...
# 40037   -8.166459e-23
# 40038   -2.414528e-22
# 40039   -8.166459e-23
# 40040   -2.414528e-22
# 40041   -8.166459e-23
# Name: I(VP1), Length: 20031, dtype: float64
# Index
# 60050    2.176283e-24
# 60051   -2.176283e-24
# 60052    2.176283e-24
# 60053   -2.176283e-24
# 60054    2.176283e-24
#              ...
# 78084    1.861914e-18
# 78085    1.839818e-18
# 78086    1.817990e-18
# 78087    1.796415e-18
# 78088    1.775102e-18
# Name: I(VP1), Length: 18039, dtype: float64
# Index
# 85089   -1.321769e-24
# 85090    1.321769e-24
# 85091   -1.321769e-24
# 85092    1.321769e-24
# 85093   -1.321769e-24
#              ...
# 95115   -8.168159e-23
# 95116   -2.414358e-22
# 95117   -8.168159e-23
# 95118   -2.414358e-22
# 95119   -8.168159e-23
# Name: I(VP1), Length: 10031, dtype: float64
# 0.39066102590350904
# 1.7374960096586967e-11
# 1.6916006729527272e-11
# -6.766846526387454e-63

# %%
cir = 'valve_flow_test_3_1_n3.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3.cir.log
# plot: valve_flow_test_3_1_n3.cir.prn
# plot: valve_flow_test_3_1_n3.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# *vs_p1 11 0 PULSE(0 105kV  0.5   1m 1m 20m 60m)
# *vs_p2 12 0 PULSE(0 6.9kV  0.51  1m 1m 30m 60m)
# *vs_p3 13 0 PULSE(0 105kV  0.53  1m 1m 20m 60m)
# vs_p1 11 0 PULSE(105kV 0   0.56   1m 1m 60m  300m)
# vs_p2 12 0 PULSE(6.9kV 0   0.56   1m 1m 180m 300m)
# vs_p3 13 0 PULSE(105kV 0   0.68   1m 1m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V            valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V            valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.0001 3s 0s 0.001
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 1107    0.0
# 1108    0.0
# 1109    0.0
# 1110    0.0
# 1111    0.0
#        ...
# 2326    0.0
# 2327    0.0
# 2328    0.0
# 2329    0.0
# 2330    0.0
# Name: I(VP1), Length: 1224, dtype: float64
# 10.79001106084367

# %%
cir = 'valve_flow_test_3_1_n3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n3_1.cir.log
# plot: valve_flow_test_3_1_n3_1.cir.prn
# plot: valve_flow_test_3_1_n3_1.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# *vs_p1 11 0 PULSE(0 105kV   0.56   1m 1m 60m  300m)
# *vs_p2 12 0 PULSE(0 6.9kV   0.56   1m 1m 180m 300m)
# *vs_p3 13 0 PULSE(0 105kV   0.68   1m 1m 120m 300m)
# vs_p1 11 0 PULSE(105kV 0   0.56   1m 1m 60m  300m)
# vs_p2 12 0 PULSE(6.9kV 0   0.56   1m 1m 180m 300m)
# vs_p3 13 0 PULSE(105kV 0   0.68   1m 1m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3_1 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.1s 0.4s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# 6075
# 16230
# start:6075 end:16230
# Index
# 6075     0.0
# 6076     0.0
# 6077     0.0
# 6078     0.0
# 6079     0.0
#         ...
# 16225    0.0
# 16226    0.0
# 16227    0.0
# 16228    0.0
# 16229    0.0
# Name: I(VP1), Length: 10155, dtype: float64
# 5.077200733807963

# %%
cir = 'valve_flow_test_3_1_n4.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n4.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n4.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n4.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n4.cir.log
# plot: valve_flow_test_3_1_n4.cir.prn
# plot: valve_flow_test_3_1_n4.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# *vs_p1 11 0 PULSE(0 105kV  0.5   1m 1m 20m 60m)
# *vs_p2 12 0 PULSE(0 6.9kV  0.51  1m 1m 30m 60m)
# *vs_p3 13 0 PULSE(0 105kV  0.53  1m 1m 20m 60m)
# vs_p1 11 0 PULSE(105kV 0  0.56   1m 1m 60m  300m)
# vs_p2 12 0 PULSE(6.9kV 0  0.56   1m 1m 180m 300m)
# vs_p3 13 0 PULSE(105kV 0  0.68   1m 1m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_4   mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# *.tran 0.0001 3s 0s 0.001
# .tran 0.01ms 2.1s 0.4s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# 6068
# 16195
# start:6068 end:16195
# Index
# 6068     0.0
# 6069     0.0
# 6070     0.0
# 6071     0.0
# 6072     0.0
#         ...
# 16190    0.0
# 16191    0.0
# 16192    0.0
# 16193    0.0
# 16194    0.0
# Name: I(VP1), Length: 10127, dtype: float64
# 53.5777166377772

# %%
cir = 'valve_flow_test_3_1_n5_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp1 = res['I(VP1)']
I_vp2 = res['I(VP2)']

# dt - 60 ms ~ 10 ul/min
I_vp1_t = sum_cur(tim, I_vp1, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp2_t = sum_cur(tim, I_vp2, [1.0, 2.0]) * 60 / 1e-9 

print(I_vp1_t)
print(I_vp2_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n5_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_1_n5_1.cir.log
# plot: valve_flow_test_3_1_n5_1.cir.prn
# plot: valve_flow_test_3_1_n5_1.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# *vs_p1 11 0 PULSE(0 105kV  0.5   1m 1m 20m 60m)
# *vs_p2 12 0 PULSE(0 6.9kV  0.51  1m 1m 30m 60m)
# *vs_p3 13 0 PULSE(0 105kV  0.53  1m 1m 20m 60m)
# vs_p1 11 0 PULSE(105kV 0   0.562  1m 1m 60m  300m)
# vs_p2 12 0 PULSE(6.9kV 0   0.560   1m 1m 180m 300m)
# vs_p3 13 0 PULSE(105kV 0   0.68   1m 1m 120m 300m)
#
# r1 1 2 1e12
# r2 5 0 1e12
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_5_1 mem1  31 12 mem_r=540e-6 fl_ch_h=60e-6
# *Ymembrane_cap_20pxV_nlin_5_1 mem1   2 21 mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.1s 0.4s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 6172     0.0
# 6173     0.0
# 6174     0.0
# 6175     0.0
# 6176     0.0
#         ...
# 16460    0.0
# 16461    0.0
# 16462    0.0
# 16463    0.0
# 16464    0.0
# Name: I(VP1), Length: 10293, dtype: float64
# Index
# 6172    -5.483391e-11
# 6173    -5.451350e-11
# 6174    -5.419497e-11
# 6175    -5.387830e-11
# 6176    -5.356347e-11
#              ...
# 16460    2.297019e-10
# 16461    2.283597e-10
# 16462    2.270254e-10
# 16463    2.256988e-10
# 16464    2.243800e-10
# Name: I(VP2), Length: 10293, dtype: float64
# 18.261783324164167
# 19.633392800226332

# %%
I_vp1_t1 = sum_cur(tim, I_vp1, [0.5, 0.8]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp2_t1 = sum_cur(tim, I_vp2, [0.6, 0.9]) 

I_vp1_t2 = sum_cur(tim, I_vp1, [0.8,  1.0]) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp2_t2 = sum_cur(tim, I_vp2, [1.25, 1.5]) 

print(I_vp1_t1)
print(I_vp1_t2)
print(I_vp2_t1)
print(I_vp2_t2)
# Out:
# Index
# 1003    0.0
# 1004    0.0
# 1005    0.0
# 1006    0.0
# 1007    0.0
#        ...
# 4081    0.0
# 4082    0.0
# 4083    0.0
# 4084    0.0
# 4085    0.0
# Name: I(VP1), Length: 3083, dtype: float64
# Index
# 2062    0.0
# 2063    0.0
# 2064    0.0
# 2065    0.0
# 2066    0.0
#        ...
# 5150    0.0
# 5151    0.0
# 5152    0.0
# 5153    0.0
# 5154    0.0
# Name: I(VP2), Length: 3093, dtype: float64
# Index
# 4086    0.0
# 4087    0.0
# 4088    0.0
# 4089    0.0
# 4090    0.0
#        ...
# 6167    0.0
# 6168    0.0
# 6169    0.0
# 6170    0.0
# 6171    0.0
# Name: I(VP1), Length: 2086, dtype: float64
# Index
# 8757     0.0
# 8758     0.0
# 8759     0.0
# 8760     0.0
# 8761     0.0
#         ...
# 11340    0.0
# 11341    0.0
# 11342    0.0
# 11343    0.0
# 11344    0.0
# Name: I(VP2), Length: 2588, dtype: float64
# 1.3593010649133072e-10
# 1.2798529283925366e-10
# -2.333893300110002e-12
# 0.0

# %%
cir = 'valve_flow_test_3_2.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP2)']

I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2.cir.log
# plot: valve_flow_test_3_2.cir.prn
# plot: valve_flow_test_3_2.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 105kV 15 105kV 15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# vs_p1 11 0 PULSE(0 105kV 0.5   1m 1m 10m 30m)
# vs_p2 12 0 PULSE(0 0.254kV  0.505 1m 1m 15m 30m)
# vs_p3 13 0 PULSE(0 105kV 0.515 1m 1m 10m 30m)
#
# r1 1 2 1k
# r2 5 0 1k
#
#
# Yvalve_20px_1_V        valv1 3 31 11 0
# Ymembrane_cap_20pxV_Pn mem1  31 12
# Yvalve_20px_1_V        valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.0001 2s
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# 1592
# 4718
# start:1592 end:4718
# Index
# 1592    0.000000e+00
# 1593    0.000000e+00
# 1594    0.000000e+00
# 1595    0.000000e+00
# 1596    0.000000e+00
#             ...
# 4713   -5.233970e-46
# 4714   -1.044049e-53
# 4715    4.176195e-53
# 4716   -4.176195e-53
# 4717    4.176195e-53
# Name: I(VP2), Length: 3126, dtype: float64
# 0.0023363736754553415

# %%
cir = 'valve_flow_test_3_2_n3.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP2)']

I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3.cir.log
# plot: valve_flow_test_3_2_n3.cir.prn
# plot: valve_flow_test_3_2_n3.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# vs_p1 11 0 PULSE(0 105kV   0.5   1m 1m 20m 60m)
# vs_p2 12 0 PULSE(0 69kV   0.51  1m 1m 30m 60m)
# vs_p3 13 0 PULSE(0 105kV   0.53  1m 1m 20m 60m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_20px_1_V            valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_20px_1_V            valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.0001 3s 0s 0.001
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# 3052
# 8136
# start:3052 end:8136
# Index
# 3052   -2.471654e-22
# 3053    2.471654e-22
# 3054   -1.533033e-33
# 3055    3.066159e-33
# 3056   -3.485670e-33
#             ...
# 8131   -1.321683e-13
# 8132   -1.230924e-13
# 8133   -1.146397e-13
# 8134   -1.067675e-13
# 8135   -9.943586e-14
# Name: I(VP2), Length: 5084, dtype: float64
# 321.6805399924422

# %%
cir = 'valve_flow_test_3_2_n3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n3_1.cir.log
# plot: valve_flow_test_3_2_n3_1.cir.prn
# plot: valve_flow_test_3_2_n3_1.cir.prn
# vs_f 1  0 0V
# *vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# *vs_p2 12 0 PWL(0s 0V    6 0v    6.1 27kV  15 27kV  15.1   0V    20 0kV)
# *vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# vs_p1 11 0 PULSE(105kV 0kV   0.56   5m 5m 60m  300m)
# vs_p2 12 0 PULSE(69kV 0kV    0.56   5m 5m 180m 300m)
# vs_p3 13 0 PULSE(105kV 0kV   0.68   5m 5m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3_1 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.0001 3s 0s 0.001
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 1118    0.0
# 1119    0.0
# 1120    0.0
# 1121    0.0
# 1122    0.0
#        ...
# 2370    0.0
# 2371    0.0
# 2372    0.0
# 2373    0.0
# 2374    0.0
# Name: I(VP1), Length: 1257, dtype: float64
# 12.28072721186891

# %%
cir = 'valve_flow_test_3_2_n5_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
#I_vp_t1 = sum_cur(tim, I_vp, [0.5,  0.75]) * 1e12 # 3s -> 1 min ; m^3 -> mm^3 = uL
#I_vp_t2 = sum_cur(tim, I_vp, [0.8,  1.00]) * 1e12 
#I_vp_t3 = sum_cur(tim, I_vp, [1.25, 1.50]) * 1e12 
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
print(f"flow: {I_vp_t* 60 / 1e-9}") 
#print(I_vp_t1)
#print(I_vp_t2)
#print(I_vp_t3)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1.cir.log
# plot: valve_flow_test_3_2_n5_1.cir.prn
# plot: valve_flow_test_3_2_n5_1.cir.prn
# * one stop valve per device
#
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(69kV 0kV   0.56   5m 5m 60m  300m)
# vs_p2 12 0 PULSE(69kV 0kV   0.561  5m 5m 180m 300m)
# vs_p3 13 0 PULSE(69kV 0kV   0.68   5m 5m 120m 300m)
#
# r1 1 2 1e12
# r2 5 0 1e12
#
#
# Yvalve_sw_20px_1_V              valv1 3  31 11 0 threshold_pressure_kPa=60e3
# Ymembrane_cap_20pxV_nlin_5_1 mem1  31 12 mem_r=504e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0 threshold_pressure_kPa=60e3
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.1s 0.4s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 6089     0.0
# 6090     0.0
# 6091     0.0
# 6092     0.0
# 6093     0.0
#         ...
# 16266    0.0
# 16267    0.0
# 16268    0.0
# 16269    0.0
# 16270    0.0
# Name: I(VP1), Length: 10182, dtype: float64
# 8.415238047711768e-11
# flow: 5.049142828627061

# %%
cir = 'valve_flow_test_3_2_n5_1_p1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp1 = res['I(VP1)']
I_vp2 = res['I(VP2)']

#I_vp3 = res['I(VP3)']

# dt - 60 ms ~ 10 ul/min
I_vp_t1 = sum_cur(tim, I_vp1) # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp_t2 = sum_cur(tim, I_vp2) # 3s -> 1 min ; m^3 -> mm^3 = uL
#I_vp_t3 = sum_cur(tim, I_vp3, [0.5, 0.7]) # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t1)
print(I_vp_t2)
#print(I_vp_t3)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_p1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_p1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_p1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_p1.cir.log
# plot: valve_flow_test_3_2_n5_1_p1.cir.prn
# plot: valve_flow_test_3_2_n5_1_p1.cir.prn
# * one stop valve per device
#
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(69kV 0kV   0.56   10m 10m 60m  500m)
# vs_p2 12 0 PULSE(69kV 0kV   0.561  10m 10m 180m 500m)
# vs_p3 13 0 PULSE(69kV 0kV   0.68   10m 10m 120m 500m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3  31 11 0 threshold_pressure_kPa=60e3
# Ymembrane_cap_20pxV_nlin_5_1    mem1  31 12      mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4  13 0 threshold_pressure_kPa=60e3
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# r3 1 41 1e12
# Ymembrane_cap_20pxV_nlin_5_1    mem2  41 12      mem_r=540e-6 fl_ch_h=60e-6
#
# vp3 0 41 0V
#
# .tran 0.01ms 1.0s 0.5s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# *I(vp3)
# .end
# Series([], Name: I(VP1), dtype: float64)
# Series([], Name: I(VP2), dtype: float64)
# 3.232516900436455e-11
# 3.231014780313579e-11

# %%
cir = 'valve_flow_test_3_2_n5_1_1s.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_1s.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_1s.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_1s.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_3_2_n5_1_1s.cir.log
# plot: valve_flow_test_3_2_n5_1_1s.cir.prn
# plot: valve_flow_test_3_2_n5_1_1s.cir.prn
# * one stop valve per device
#
# vs_f 1  0 0V
#
# vs_p11 111 0 PULSE(69kV 0kV   0.56   5m 5m 60m  300m)
# vs_p21 121 0 PULSE(69kV 0kV   0.56   5m 5m 180m 300m)
# vs_p31 131 0 PULSE(69kV 0kV   0.68   5m 5m 120m 300m)
#
# vs_p12 112 0 PULSE(69kV 0kV   0.56    5m 5m 60m  300m)
# vs_p22 122 0 PULSE(69kV 0kV   0.56    5m 5m 180m 300m)
# vs_p32 132 0 PULSE(69kV 0kV   0.68    5m 5m 120m 300m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3  31 111 0 threshold_pressure_kPa=60e3
# Ymembrane_cap_20pxV_nlin_5_1 mem1  31 112 mem_r=540e-6 fl_ch_h=60e-6
#
# Yvalve_sw_20px_1_V              valv2 31 32 121 0 threshold_pressure_kPa=60e3
# Ymembrane_cap_20pxV_nlin_5_1 mem2  32 122 mem_r=540e-6 fl_ch_h=60e-6
#
# Yvalve_sw_20px_1_V              valv3 32 33 131 0 threshold_pressure_kPa=60e3
# Ymembrane_cap_20pxV_nlin_5_1 mem3  33 132 mem_r=540e-6 fl_ch_h=60e-6
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.1s 0.4s 0.1ms
# .print tran I(vp1) I(vp2) V(111) V(121) V(131)
# .end
# Index
# 6269     0.0
# 6270     0.0
# 6271     0.0
# 6272     0.0
# 6273     0.0
#         ...
# 16819    0.0
# 16820    0.0
# 16821    0.0
# 16822    0.0
# 16823    0.0
# Name: I(VP1), Length: 10555, dtype: float64
# -113.42527065539649

# %%
cir = 'valve_flow_test_4_0_n3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [1.0, 2.0]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n3_1.cir.log
# plot: valve_flow_test_4_0_n3_1.cir.prn
# plot: valve_flow_test_4_0_n3_1.cir.prn
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(105kV 0kV   0.53   5m 5m 30m 150m)
# vs_p2 12 0 PULSE(69kV 0kV    0.53   5m 5m 90m 150m)
# vs_p3 13 0 PULSE(105kV 0kV   0.59   5m 5m 60m 150m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3_1 mem1  31 12 mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 3s 0s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 10191    5.880005e-12
# 10192    5.582045e-12
# 10193    5.299184e-12
# 10194    5.030657e-12
# 10195    4.775736e-12
#              ...
# 20630    0.000000e+00
# 20631    0.000000e+00
# 20632    0.000000e+00
# 20633    0.000000e+00
# 20634    0.000000e+00
# Name: I(VP1), Length: 10444, dtype: float64
# 11.630360952120629

# %%
cir = 'valve_flow_test_4_0_n5_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp = res['I(VP1)']

# dt - 60 ms ~ 10 ul/min
I_vp_t = sum_cur(tim, I_vp, [0.8, 1.8]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n5_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_0_n5_1.cir.log
# plot: valve_flow_test_4_0_n5_1.cir.prn
# plot: valve_flow_test_4_0_n5_1.cir.prn
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(105kV 0kV   0.53   5m 5m 30m 150m)
# vs_p2 12 0 PULSE(69kV 0kV    0.53   5m 5m 90m 150m)
# vs_p3 13 0 PULSE(105kV 0kV   0.59   5m 5m 60m 150m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_5_1 mem1  31 12 mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.3s 0s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 8098     0.0
# 8099     0.0
# 8100     0.0
# 8101     0.0
# 8102     0.0
#         ...
# 18437    0.0
# 18438    0.0
# 18439    0.0
# 18440    0.0
# 18441    0.0
# Name: I(VP1), Length: 10344, dtype: float64
# 9.421302437327398

# %%
cir = 'valve_flow_test_4_1_n5_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp1 = res['I(VP1)']
I_vp2 = res['I(VP2)']

# dt - 60 ms ~ 10 ul/min
I_vp1_t = sum_cur(tim, I_vp1, [0.8, 1.8]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp2_t = sum_cur(tim, I_vp2, [0.8, 1.8]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp1_t)
print(I_vp2_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n5_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n5_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n5_1.cir.log
# plot: valve_flow_test_4_1_n5_1.cir.prn
# plot: valve_flow_test_4_1_n5_1.cir.prn
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(105kV 0kV   0.52   5m 5m 20m 100m)
# vs_p2 12 0 PULSE(69kV 0kV    0.52   5m 5m 60m 100m)
# vs_p3 13 0 PULSE(105kV 0kV   0.56   5m 5m 40m 100m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_5_1 mem1  31 12 mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 2.3s 0s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 8149     0.0
# 8150     0.0
# 8151     0.0
# 8152     0.0
# 8153     0.0
#         ...
# 18654    0.0
# 18655    0.0
# 18656    0.0
# 18657    0.0
# 18658    0.0
# Name: I(VP1), Length: 10510, dtype: float64
# Index
# 8149     2.403422e-22
# 8150    -8.014895e-23
# 8151     9.124328e-23
# 8152    -2.497736e-22
# 8153     2.362378e-22
#              ...
# 18654   -2.918500e-22
# 18655    2.247288e-22
# 18656   -5.291774e-23
# 18657    7.619695e-23
# 18658   -2.481074e-22
# Name: I(VP2), Length: 10510, dtype: float64
# 12.757289051672021
# 15.3114394695412

# %%
cir = 'valve_flow_test_4_1_n3_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
        
        
res = plot_result.load_prn(prn_f)
tim  = res['TIME'] 
I_vp1 = res['I(VP1)']
I_vp2 = res['I(VP2)']

# dt - 60 ms ~ 10 ul/min
I_vp1_t = sum_cur(tim, I_vp1, [0.8, 1.8]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL
I_vp2_t = sum_cur(tim, I_vp2, [0.8, 1.8]) * 60 / 1e-9 # 3s -> 1 min ; m^3 -> mm^3 = uL

print(I_vp1_t)
print(I_vp2_t)
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n3_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n3_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_4_1_n3_1.cir.log
# plot: valve_flow_test_4_1_n3_1.cir.prn
# plot: valve_flow_test_4_1_n3_1.cir.prn
# vs_f 1  0 0V
#
# vs_p1 11 0 PULSE(105kV 0kV   0.52   5m 5m 20m 100m)
# vs_p2 12 0 PULSE(69kV 0kV    0.52   5m 5m 60m 100m)
# vs_p3 13 0 PULSE(105kV 0kV   0.56   5m 5m 40m 100m)
#
# r1 1 2 1e11
# r2 5 0 1e11
#
#
# Yvalve_sw_20px_1_V              valv1 3 31 11 0
# Ymembrane_cap_20pxV_nlin_3_1 mem1  31 12 mem_r=540e-6 fl_ch_h=60e-6
# Yvalve_sw_20px_1_V              valv2 31 4 13 0
#
# vp1 2 3 0V
# vp2 4 5 0V
#
# .tran 0.01ms 3s 0s 0.1ms
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end
# Index
# 8170     0.0
# 8171     0.0
# 8172     0.0
# 8173     0.0
# 8174     0.0
#         ...
# 18749    0.0
# 18750    0.0
# 18751    0.0
# 18752    0.0
# 18753    0.0
# Name: I(VP1), Length: 10584, dtype: float64
# Index
# 8170    -9.182906e-21
# 8171     9.182906e-21
# 8172    -9.182906e-21
# 8173     9.182906e-21
# 8174    -9.182906e-21
#              ...
# 18749    9.182912e-21
# 18750   -9.182912e-21
# 18751    9.182912e-21
# 18752   -9.182912e-21
# 18753    9.182912e-21
# Name: I(VP2), Length: 10584, dtype: float64
# 16.983022456869048
# 20.895736246141894

# %%
cir = 'valve_flow_test_1_0_nonlin.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')

with open(val_t_dir+'/'+cir, 'r') as f:
    for l in f:
        print(l.replace('\n', ''))
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_1_0_nonlin.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_1_0_nonlin.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_1_0_nonlin.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/JupyterTesting/../MFlibrary_testing/stdcellTesting/valve_flow/valve_flow_test_1_0_nonlin.cir.log
# plot: valve_flow_test_1_0_nonlin.cir.prn
# plot: valve_flow_test_1_0_nonlin.cir.prn
# vs_f 1  0 5V
# vs_p1 11 0 PWL(0s 105kV 3 105kV 3.1 0kV   12 0kV   12.1   105kV 20 105kV)
# vs_p2 12 0 PWL(0s 0V    6 0v    6.1 105kV 15 105kV 15.1   0V    20 0kV)
# vs_p3 13 0 PWL(0s 105kV 9 105kV 9.1 0kV   18 0kV   18.1   105kV 20 105kV)
#
# r1 1 2 1k
# r2 5 0 1k
#
#
# Yvalve_20px_1_V        valv1 3 31 11 0
# Ymembrane_cap_20pxV_Pn mem1  31 12
# Yvalve_20px_1_V        valv2 31 4 13 0
#
# vp1 3 2 0V
# vp2 5 4 0V
#
# .tran 0.01 20s
# .print tran I(vp1) I(vp2) V(11) V(12) V(13)
# .end

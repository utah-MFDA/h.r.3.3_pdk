# %%
import matplotlib

import sys, os
import subprocess

#print(os.getcwd())
sys.path.insert(0,os.getcwd()+'/../')

import plot_result

val_t_dir = os.path.normpath(os.getcwd()+'/../MFlibrary_testing/stdcellTesting/valves')
plot_r = plot_result.plot_prn

lib = "./../../Components/verilogA_build/lib/MFXyce.so"

def run_xyce(lib, cir):
    if not os.path.isfile(lib):
        raise ValueError(lib + " library file does not exist") 

    if not os.path.isfile(cir):
        raise ValueError(cir + " not able to find ciruit file") 

    cir_root, fname = os.path.split(cir)
    
    subprocess.run(['sh', './../run_test.sh', lib, cir, cir_root])

def run_and_plot(lib, cir, plot_type=None, plot_nodes=None):

    cir_a = val_t_dir+'/'+cir
    prn   = val_t_dir+'/results/'+cir+'.prn'
    
    run_xyce(lib, cir_a)
    
    # only the definition above needs to be changed
    run_xyce(lib, cir_a)
    plot_r(prn, plot_type=plot_type, plot_nodes=plot_nodes)
#def run_and_plot(lib, cir):
#
#    cir_a = val_t_dir+'/'+cir
#    prn   = val_t_dir+'/results/'+cir+'.prn'
#    
#    run_xyce(lib, cir_a)
#    
#    # only the definition above needs to be changed
#    run_xyce(lib, cir_a)
#    plot_r(prn)

# %%
#plot_r(val_t_dir+'/results/valve_test_1_1.cir.prn')
cir = 'valve_test_1_1.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir.log
# plot: valve_test_1_1.cir.prn
# plot: valve_test_1_1.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_test_1_2.cir.prn')

# %%
#plot_r(val_t_dir+'/results/valve_test_1_3.cir.prn')
cir = 'valve_test_1_2.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2.cir.log
# plot: valve_test_1_2.cir.prn
# plot: valve_test_1_2.cir.prn

# %%
#plot_r(val_t_dir+'/results/valve_test_1_3_I.cir.prn')
cir = 'valve_test_1_3.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3.cir.log
# plot: valve_test_1_3.cir.prn
# plot: valve_test_1_3.cir.prn

# %%
#plot_r(val_t_dir+'/results/valve_test_1_4.cir.prn')
cir = 'valve_test_1_4.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_4.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_4.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_4.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_4.cir.log
# plot: valve_test_1_4.cir.prn
# plot: valve_test_1_4.cir.prn

# %%
cir = 'valve_test_1_1_V.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1_V.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1_V.cir.log
# plot: valve_test_1_1_V.cir.prn
# plot: valve_test_1_1_V.cir.prn

# %%
cir = 'valve_test_1_2_V.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2_V.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_2_V.cir.log
# plot: valve_test_1_2_V.cir.prn
# plot: valve_test_1_2_V.cir.prn

# %%
cir = 'valve_test_1_3_V.cir'
prn_f = val_t_dir+'/results/'+cir+'.prn'
run_and_plot(lib, cir, plot_type="flow")
plot_r(prn_f, plot_type='voltage')
# Out:
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3_V.cir.log
# Xyce -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3_V.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_3_V.cir.log
# plot: valve_test_1_3_V.cir.prn
# plot: valve_test_1_3_V.cir.prn

# %%
plot_r(val_t_dir+'/results/valve_test_1.cir.prn')

# %%
cir = 'valve_test_1_1.cir'
run_and_plot(lib, cir)
# only the definition above needs to be changed
#cir_a = val_t_dir+'/'+cir
#prn   = val_t_dir+'/results/'+cir+'.prn'
#run_xyce(lib, cir_a)
#plot_r(prn)
# Out:
# -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir.log
# -plugin ./../../Components/verilogA_build/lib/MFXyce.so /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir > /home/u1146591/MFDA/h.r.3.3_pdk/xyce_testing/MFlibrary_testing/stdcellTesting/valves/valve_test_1_1.cir.log
# plot: valve_test_1_1.cir.prn
